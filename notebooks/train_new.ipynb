# %%
using Pkg
Pkg.activate("/home/manu/Documents/Work/NormalFormAE/.")
using NormalFormAE, Flux, Zygote, Plots
include("problems/nf.jl")
include("/home/manu/Documents/Work/NFAE_old/run/run_nf.jl")

x_model_name = :nf
z_model_name = :Hopf
x_dim = 128
par_dim = 1
z_dim = 2
tsize = 500
tspan = [0.0,200.0]
xVar = 0.1
aVar = 0.5
mean_ic_x = [0.0] 
mean_ic_a = [0.0]
x_rhs = dxdt_rhs
x_solve = dxdt_solve 
 

model_x = xModel(x_model_name, x_dim, par_dim, tsize,tspan,xVar,aVar,mean_ic_x,mean_ic_a,x_rhs,x_solve)
model_z = NormalForm(:Hopf,z_dim ,par_dim, dzdt_rhs, dzdt_solve)

state = AE(:State, 128,2, [64,32,16],:elu,gpu)
par = AE(:Par, 1,1,[16,16],:elu,gpu)
trans = nothing


tscale_init = [1f0] |> gpu

training_size = 1000
test_size = 100


data_dir = "NormalFormAEData"

P_reg = [1.0f0, 1.0f0, 1.0f0, 0.001f0, 0.001f0, 1.0f0, 1.0f0]


nfae = NFAE(:nf, :Hopf, model_x, model_z, training_size, test_size, state, par, nothing, tscale_init,
                       P_reg,gpu, 10,0.5,0.1,data_dir)


load_posttrain(nfae)
# Out:
#  Activating environment at `~/Documents/Work/NormalFormAE/Project.toml`
# ┌ Info: Precompiling NormalFormAE [cee5ac90-b15b-4c5b-bec8-96edad4e3b41]
# └ @ Base loading.jl:1260
# ERROR: LoadError: UndefVarError: LLVMPtr not defined
# Stacktrace:
#  [1] include(::Module, ::String) at ./Base.jl:377
#  [2] top-level scope at none:2
#  [3] eval at ./boot.jl:331 [inlined]
#  [4] eval(::Expr) at ./client.jl:449
#  [5] top-level scope at ./none:3
# in expression starting at /home/manu/.julia/packages/CUDA/0p5fn/src/CUDA.jl:9
# ERROR: LoadError: Failed to precompile CUDA [052768ef-5323-5732-b1bb-66c8b64840ba] to /home/manu/.julia/compiled/v1.4/CUDA/oWw5k_CqJhf.ji.
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] compilecache(::Base.PkgId, ::String) at ./loading.jl:1272
#  [3] _require(::Base.PkgId) at ./loading.jl:1029
#  [4] require(::Base.PkgId) at ./loading.jl:927
#  [5] require(::Module, ::Symbol) at ./loading.jl:922
#  [6] include(::Module, ::String) at ./Base.jl:377
#  [7] top-level scope at none:2
#  [8] eval at ./boot.jl:331 [inlined]
#  [9] eval(::Expr) at ./client.jl:449
#  [10] top-level scope at ./none:3
# in expression starting at /home/manu/.julia/packages/Flux/q3zeA/src/Flux.jl:30
# ERROR: LoadError: Failed to precompile Flux [587475ba-b771-5e3f-ad9e-33799f191a9c] to /home/manu/.julia/compiled/v1.4/Flux/QdkVy_CqJhf.ji.
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] compilecache(::Base.PkgId, ::String) at ./loading.jl:1272
#  [3] _require(::Base.PkgId) at ./loading.jl:1029
#  [4] require(::Base.PkgId) at ./loading.jl:927
#  [5] require(::Module, ::Symbol) at ./loading.jl:922
#  [6] include(::Module, ::String) at ./Base.jl:377
#  [7] top-level scope at none:2
#  [8] eval at ./boot.jl:331 [inlined]
#  [9] eval(::Expr) at ./client.jl:449
#  [10] top-level scope at ./none:3
# in expression starting at /home/manu/Documents/Work/NormalFormAE/src/NormalFormAE.jl:3
# Failed to precompile NormalFormAE [cee5ac90-b15b-4c5b-bec8-96edad4e3b41] to /home/manu/.julia/compiled/v1.4/NormalFormAE/y96ht_CqJhf.ji.
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] compilecache(::Base.PkgId, ::String) at ./loading.jl:1272
#  [3] _require(::Base.PkgId) at ./loading.jl:1029
#  [4] require(::Base.PkgId) at ./loading.jl:927
#  [5] require(::Module, ::Symbol) at ./loading.jl:922
#  [6] top-level scope at In[1]:3
